# %% [markdown]
# ## Part 1

# %%
from sklearn.datasets import load_iris
iris = load_iris()

# %%
print(iris['DESCR'])
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 150 (50 in each of three classes)
#     :Number of Attributes: 4 numeric, predictive attributes and the class
#     :Attribute Information:
#         - sepal length in cm
#         - sepal width in cm
#         - petal length in cm
#         - petal width in cm
#         - class:
#                 - Iris-Setosa
#                 - Iris-Versicolour
#                 - Iris-Virginica
#
#     :Summary Statistics:
#
#     ============== ==== ==== ======= ===== ====================
#                     Min  Max   Mean    SD   Class Correlation
#     ============== ==== ==== ======= ===== ====================
#     sepal length:   4.3  7.9   5.84   0.83    0.7826
#     sepal width:    2.0  4.4   3.05   0.43   -0.4194
#     petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
#     petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
# ...

# %%
X = iris['data']
y = iris['target']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dectree = DecisionTreeClassifier()
dectree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_test_pred = dectree.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, f1_score
ac_sc = accuracy_score(y_test, y_test_pred)
f1_sc = f1_score(y_test, y_test_pred, average='weighted')
print("Accuracy:", ac_sc)
print("F1_Score:", f1_sc)
# Out:
# Accuracy: 0.9333333333333333
# F1_Score: 0.933068783068783

# %%
from sklearn import tree
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(dectree, 
                   feature_names=iris.feature_names,  
                   class_names=iris.target_names,
                   filled=True)

# %% [markdown]
# ## Part 2

# %%
X = [[i for i in j] for j in iris['data']]
y = [i for i in iris['target']]

# %%
from data_science.machine_learning import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4)

# %%
from data_science import Decision_Tree

# %%
dt = Decision_Tree()

# %%
tree = dt.build_tree_id3(inputs=X_train, 
                         split_attributes['sepal_length', 'sepal_width', 'petal_length', 'petal_width'],
                        target_attribute='target')
# Out:
#   Input In [39]
#     target_attribute='target')
#                              ^
# SyntaxError: positional argument follows keyword argument
